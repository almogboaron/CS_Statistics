# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sci

# %%
from scipy.stats import binom as bn
X = bn.rvs(n = 20,p = 0.2,size = 10)

# %%
X
# Out:
# array([7, 3, 6, 1, 3, 7, 5, 5, 9, 4])

# %%
bn.cdf([1,4,5],10,0.2)
# Out:
# array([0.37580964, 0.9672065 , 0.99363062])

# %%
Y=bn.cdf(X,10,0.2)

# %%
plt.scatter(X,Y)

# %%
plt.plot(X,Y)

# %%
plt.scatter(X,Y)
plt.plot(X,Y)
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
